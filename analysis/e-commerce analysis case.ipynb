# %% [markdown]
# ## Task planning & Goal:
# ### Metrics/hypothesis for generating data insights
# ###### 1. Customer
# - Business model: conversion, retention and generate revenue, customer turnover, LTV
# - Customer churn, repurchase rate to measure "stickness"(retention) and loyalty/-purchase behaviors of customer
# - ==> Build the function that will generate the "cohorts"
# - New Customer acquisition(time base: monthly)
# - is discount promotion increase sales or new customers acquisition(H0)
#
# ###### 2. Product: 4P rule
# - Products-> Pricing -> Place(online, if Omi-channel?-> offline: demographic city/region)
#
# ###### 3. ML
# - Timeseries analysis: Sales and Profits
# - Sales target section(model: linear regression, using Sklearn), to show confidence for the future sales.
# - Anomaly detetcion: For e-commerce there are always some fake purchases
# - Cluserting, TODO
#
# ### Workflow
# - Data analysis for cleaning and aggregation
# - Build Small Database (MySQL)
# - Connect Database with Apache Superset and deploy
# - Optional use Tableau
# - Predictive analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# build helper functions
FILE_PATH= "Data Analyst Case Chaoly.xlsx"
def get_data(base_file: str, tab_nb: int, order_date: str=None, ship_date: str=None)-> pd.DataFrame:
    return pd.read_excel(base_file,
                         tab_nb,
                        parse_date = ["order_date","ship_date"],
                        infer_datetime_format = True)

# %%
# read dataset
ListOfOrders = get_data(FILE_PATH, 0, "Order Date", "Ship Date")
OrderBreakdown = get_data(FILE_PATH, 1)
SalesTargets = get_data(FILE_PATH, 2)

# %% [markdown]
# #### EDA
# - check is any Null values, if then dropna
#
# - check row-wise duplicated ->remove

# %%
def isnull(df):
    return df.isnull().any()

# %%
isnull(ListOfOrders)
# Out:
# Order ID         False
# Order Date       False
# Customer Name    False
# City             False
# Country          False
# Region           False
# Segment          False
# Ship Date        False
# Ship Mode        False
# State            False
# dtype: bool

# %%
isnull(OrderBreakdown)
isnull(SalesTargets)
# Out:
# Month of Order Date    False
# Category               False
# Target                 False
# dtype: bool

# %%
ListOfOrders.duplicated().any()
# Out:
# False

# %%
OrderBreakdown.duplicated().any()
# OrderBreakdown.columns
# Out:
# True

# %%
OrderBreakdown[OrderBreakdown.duplicated("Order ID")]
# Out:
#              Order ID                                       Product Name  \
# 4     BN-2011-2819714                        Eldon Folders, Single Width
# 6      AZ-2011-617423                        Sanford Canvas, Fluorescent
# 8     AZ-2011-2918397                  Accos Thumb Tacks, Assorted Sizes
# 9     AZ-2011-2918397                          Smead Lockers, Industrial
# 11    BN-2011-3248724                    Binney & Smith Sketch Pad, Blue
# 13    AZ-2011-7053593                        Binney & Smith Canvas, Blue
# 16    AZ-2011-4827146                          Smead Trays, Single Width
# 17    AZ-2011-6439906           Novimex File Folder Labels, Alphabetical
# 22    AZ-2011-5702370                        Binney & Smith Canvas, Blue
# 23    AZ-2011-5702370                             Ibico Index Tab, Clear
# 24    AZ-2011-5702370                               Epson Printer, White
# 26    BN-2011-4913858  Harbour Creations Legal Exhibit Labels, Laser ...
# 27    BN-2011-4913858            Green Bar Cards & Envelopes, Multicolor
# 28    BN-2011-4913858                                Smead Lockers, Blue
# 31    AZ-2011-5960662                       StarTech Card Printer, White
# 32    AZ-2011-5960662                      Apple Headset, with Caller ID
# 34    AZ-2011-7675351  Harbour Creations Removable Labels, 5000 Label...
# 35    AZ-2011-7675351        Green Bar Computer Printout Paper, 8.5 x 11
# 36    AZ-2011-7675351                     Elite Letter Opener, Easy Grip
# 37    AZ-2011-7675351                        Hewlett Copy Machine, Laser
# 42    AZ-2011-5342265                             Fellowes Folders, Blue
# 48    AZ-2011-2245674                              Tenex File Cart, Blue
# 49    AZ-2011-8034411                          Boston Canvas, Easy-Erase
# 50    AZ-2011-8034411                       Rogers Lockers, Single Width
# 52    BN-2011-7883641                 Office Star Bag Chairs, Set of Two
# 53    BN-2011-7883641                          Advantus Staples, 12 Pack
# 54    BN-2011-7883641   Harbour Creations Color Coded Labels, Adjustable
# 55    BN-2011-7883641                     SanDisk Memo Slips, Multicolor
# 59    AZ-2011-4205736                             Cardinal Binder, Clear
# 61    AZ-2011-5708655                              Avery Binder, Economy
# ...               ...                                                ...
# 7992  AZ-2014-9733542                         Cisco Signal Booster, VoIP
# 7993  AZ-2014-9733542                        Cisco Smart Phone, Cordless
# 7996  BN-2014-6319094                       Fellowes Lockers, Wire Frame
# 7998  BN-2014-6319094                        Panasonic Card Printer, Red
# 8000   AZ-2014-494283                         Eldon Shelving, Wire Frame
# 8002  AZ-2014-9491986                          Xerox Note Cards, Premium
# 8004   AZ-2014-338779                            BIC Canvas, Water Color
# 8005   AZ-2014-338779                      Boston Sketch Pad, Easy-Erase
# 8006   AZ-2014-338779                       Sanford Markers, Fluorescent
# 8007   AZ-2014-338779                        Acco 3-Hole Punch, Recycled
# 8008   AZ-2014-338779                              Avery Binder, Durable
# 8009   AZ-2014-338779                           Fellowes File Cart, Blue
# 8012  AZ-2014-6752912                     Lesro Round Table, Rectangular
# 8013  AZ-2014-6752912                            Hoover Microwave, White
# 8014  AZ-2014-6752912                  Cardinal Binding Machine, Economy
# 8015  AZ-2014-6752912                Xerox Cards & Envelopes, Multicolor
# 8016  AZ-2014-6752912                            Eldon Trays, Wire Frame
# 8017  AZ-2014-6752912            Motorola Signal Booster, with Caller ID
# 8019  BN-2014-4912801                         Sanford Highlighters, Blue
# 8021  BN-2014-3913645                        Avery 3-Hole Punch, Economy
# 8023  BN-2014-3913645                                   Sharp Ink, Laser
# 8024  AZ-2014-5388375                              StarTech Phone, White
# 8026  AZ-2014-8026360                             Epson Inkjet, Wireless
# 8027  AZ-2014-8026360                    Panasonic Card Printer, Durable
# 8031  AZ-2014-3870231                          Kleencut Ruler, Easy Grip
# 8032  AZ-2014-3870231                        Canon Fax and Copier, Laser
# 8033  AZ-2014-3870231                      Nokia Headset, with Caller ID
# 8044  BN-2014-4140795                      Avery Binder Covers, Recycled
# 8045  BN-2014-4140795                                StarTech Phone, Red
# 8046   AZ-2014-766953                          Motorola Audio Dock, VoIP
#
#       Discount  Sales  Profit  Quantity         Category Sub-Category
# 4         0.50     17      -1         2  Office Supplies      Storage
# 6         0.00    207      77         4  Office Supplies          Art
# 8         0.00     33       2         3  Office Supplies    Fasteners
# 9         0.10    716     143         4  Office Supplies      Storage
# 11        0.50    116     -56         5  Office Supplies          Art
# 13        0.00    103      20         2  Office Supplies          Art
# 16        0.00     97      31         2  Office Supplies      Storage
# 17        0.00     40       6         5  Office Supplies       Labels
# 22        0.00    257      49         5  Office Supplies          Art
# 23        0.00     17       6         2  Office Supplies      Binders
# 24        0.00    522      21         2       Technology     Machines
# 26        0.50     22     -12         4  Office Supplies       Labels
# 27        0.50     50     -38         2  Office Supplies        Paper
# 28        0.50    198    -131         2  Office Supplies      Storage
# 31        0.00    486      78         3       Technology     Machines
# 32        0.00    440      66         6       Technology       Phones
# 34        0.00     21       7         2  Office Supplies       Labels
# 35        0.00    170      25         5  Office Supplies        Paper
# 36        0.00     55       2         2  Office Supplies     Supplies
# 37        0.00    527      11         2       Technology      Copiers
# 42        0.40     48       8         3  Office Supplies      Storage
# 48        0.00    666     120         5  Office Supplies      Storage
# 49        0.00     54      12         1  Office Supplies          Art
# 50        0.40    889      59         7  Office Supplies      Storage
# 52        0.60     69     -95         3        Furniture       Chairs
# 53        0.00     41       3         4  Office Supplies    Fasteners
# 54        0.00     54       8         5  Office Supplies       Labels
# 55        0.00     55       3         3  Office Supplies        Paper
# 59        0.00    133       4        10  Office Supplies      Binders
# 61        0.00     52      20         4  Office Supplies      Binders
# ...        ...    ...     ...       ...              ...          ...
# 7992      0.00   1063      64         7       Technology       Phones
# 7993      0.00   1954     782         3       Technology       Phones
# 7996      0.50    929     -93         9  Office Supplies      Storage
# 7998      0.50    342    -103         4       Technology     Machines
# 8000      0.00    190      15         4  Office Supplies      Storage
# 8002      0.00    237      47         9  Office Supplies        Paper
# 8004      0.00    114       1         2  Office Supplies          Art
# 8005      0.00    293      85         6  Office Supplies          Art
# 8006      0.00     98      39         4  Office Supplies          Art
# 8007      0.00     91       8         3  Office Supplies      Binders
# 8008      0.00     72       4         5  Office Supplies      Binders
# 8009      0.10    247      82         2  Office Supplies      Storage
# 8012      0.35   1461     202         5        Furniture       Tables
# 8013      0.10   1104     209         4  Office Supplies   Appliances
# 8014      0.00    100      28         2  Office Supplies      Binders
# 8015      0.00    325      32         7  Office Supplies        Paper
# 8016      0.10    169      55         4  Office Supplies      Storage
# 8017      0.15    487     143         4       Technology       Phones
# 8019      0.50      8      -6         1  Office Supplies          Art
# 8021      0.50     56       0         4  Office Supplies      Binders
# 8023      0.50    373    -254         6       Technology      Copiers
# 8024      0.10    131      45         2       Technology     Machines
# 8026      0.15    524     -25         2       Technology     Machines
# 8027      0.15    148       9         1       Technology     Machines
# 8031      0.00     30       1         2  Office Supplies     Supplies
# 8032      0.00   1913     899        10       Technology      Copiers
# 8033      0.00    292      35         4       Technology       Phones
# 8044      0.50     23      -6         4  Office Supplies      Binders
# 8045      0.50    108     -19         3       Technology     Machines
# 8046      0.00    867     251         5       Technology       Phones
#
# [3930 rows x 8 columns]

# %%
SalesTargets.duplicated().any()
# Out:
# False

# %%
# ListOfOrders.tail() 
ListOfOrders[ListOfOrders["Order ID"]=="BN-2014-4140795"]
# Out:
#              Order ID Order Date    Customer Name       City      Country  \
# 4116  BN-2014-4140795 2014-12-31  Daniel Hamilton  Eindhoven  Netherlands
#
#        Region      Segment  Ship Date     Ship Mode          State
# 4116  Central  Home Office 2015-01-05  Economy Plus  North Brabant

# %%
OrderBreakdown[OrderBreakdown["Order ID"]=="BN-2014-4140795"]
# Out:
#              Order ID                       Product Name  Discount  Sales  \
# 8043  BN-2014-4140795  BIC Pencil Sharpener, Fluorescent       0.5     30
# 8044  BN-2014-4140795      Avery Binder Covers, Recycled       0.5     23
# 8045  BN-2014-4140795                StarTech Phone, Red       0.5    108
#
#       Profit  Quantity         Category Sub-Category
# 8043     -10         2  Office Supplies          Art
# 8044      -6         4  Office Supplies      Binders
# 8045     -19         3       Technology     Machines

# %%
# For each main category=>sub-category, monthly sales target below. 
SalesTargets.head()
# Out:
#   Month of Order Date   Category  Target
# 0          2011-01-01  Furniture   10000
# 1          2011-02-01  Furniture   10100
# 2          2011-03-01  Furniture   10300
# 3          2011-04-01  Furniture   10400
# 4          2011-05-01  Furniture   10500

# %%
SalesTargets.Category.unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
# merge ListofOders and OrdersBrokendown tables
# one tick: use copy() to not modify the original data sets, so that to trackback and use the raw fact data again.
FullOrderList= ListOfOrders.merge(OrderBreakdown, on="Order ID", how="left")
FullOrderList.tail()
# Out:
#              Order ID Order Date        Customer Name       City  \
# 8042  AZ-2014-1412225 2014-12-31          Leon Barnes  Worcester
# 8043  AZ-2014-7604524 2014-12-31  Rebecca Chamberlain    Hamburg
# 8044  BN-2014-4140795 2014-12-31      Daniel Hamilton  Eindhoven
# 8045  BN-2014-4140795 2014-12-31      Daniel Hamilton  Eindhoven
# 8046  BN-2014-4140795 2014-12-31      Daniel Hamilton  Eindhoven
#
#              Country   Region      Segment  Ship Date     Ship Mode  \
# 8042  United Kingdom    North     Consumer 2015-01-01      Priority
# 8043         Germany  Central  Home Office 2015-01-04       Economy
# 8044     Netherlands  Central  Home Office 2015-01-05  Economy Plus
# 8045     Netherlands  Central  Home Office 2015-01-05  Economy Plus
# 8046     Netherlands  Central  Home Office 2015-01-05  Economy Plus
#
#               State                       Product Name  Discount  Sales  \
# 8042        England    Fellowes Shelving, Single Width       0.0    289
# 8043        Hamburg    Wilson Jones Index Tab, Economy       0.0     32
# 8044  North Brabant  BIC Pencil Sharpener, Fluorescent       0.5     30
# 8045  North Brabant      Avery Binder Covers, Recycled       0.5     23
# 8046  North Brabant                StarTech Phone, Red       0.5    108
#
#       Profit  Quantity         Category Sub-Category
# 8042      75         5  Office Supplies      Storage
# 8043       8         5  Office Supplies      Binders
# 8044     -10         2  Office Supplies          Art
# 8045      -6         4  Office Supplies      Binders
# 8046     -19         3       Technology     Machines

# %%
OrderLists= FullOrderList.copy()
# OrderLists.columns

# %%
OrderLists.groupby(["Segment"])["Sales"].sum()
# Out:
# Segment
# Consumer       1236282
# Corporate       738137
# Home Office     374063
# Name: Sales, dtype: int64

# %%
# transform the date for the %y-m format 
# use this compare to sales target! 
OrderLists["Order Month"]= OrderLists["Order Date"].apply(lambda d: d.strftime("%Y-%m"))
# get actual monthly sales, categorized by "main Category"
actual_monthly_sales = OrderLists.groupby(["Order Month","Category"])["Sales", "Profit"].sum().reset_index() 
actual_monthly_sales.tail()
# Out:
#     Order Month         Category  Sales  Profit
# 139     2014-11  Office Supplies  33305    4090
# 140     2014-11       Technology  29909    2156
# 141     2014-12        Furniture  18843    2388
# 142     2014-12  Office Supplies  30133    2511
# 143     2014-12       Technology  34112    4303

# %%
# rename SalesTargets field
SalesTargets = SalesTargets.rename(columns={"Month of Order Date":"Order Month"})
SalesTargets["Order Month"] = SalesTargets["Order Month"].apply(lambda d: d.strftime("%Y-%m"))
SalesCombined = SalesTargets.merge(actual_monthly_sales, on="Order Month", how="left")
SalesCombined["Target_achieved"]= np.where((SalesCombined["Sales"] > SalesCombined["Target"]), "Achieved","Not Achieved")
SalesCombined.tail()
# Out:
#     Order Month  Category_x  Target       Category_y  Sales  Profit  \
# 427     2014-11  Technology   23000  Office Supplies  33305    4090
# 428     2014-11  Technology   23000       Technology  29909    2156
# 429     2014-12  Technology   23000        Furniture  18843    2388
# 430     2014-12  Technology   23000  Office Supplies  30133    2511
# 431     2014-12  Technology   23000       Technology  34112    4303
#
#     Target_achieved
# 427        Achieved
# 428        Achieved
# 429    Not Achieved
# 430        Achieved
# 431        Achieved

# %%
target_achieve_rate = sum(SalesCombined["Target_achieved"]=="Achieved")/SalesCombined["Target_achieved"].count() 
print(f"Acieved rate is {100 * target_achieve_rate:.2f}%")
# Out:
# Acieved rate is 55.09%

# %%
ListOfOrders.describe()
# Out:
#                Order ID           Order Date Customer Name    City Country  \
# count              4117                 4117          4117    4117    4117
# unique             4117                 1214           792     999      15
# top     AZ-2012-5204554  2014-09-16 00:00:00  Jose Gambino  London  France
# freq                  1                   13            13     113     991
# first               NaN  2011-01-01 00:00:00           NaN     NaN     NaN
# last                NaN  2014-12-31 00:00:00           NaN     NaN     NaN
#
#          Region   Segment            Ship Date Ship Mode    State
# count      4117      4117                 4117      4117     4117
# unique        3         3                 1311         4      127
# top     Central  Consumer  2014-09-22 00:00:00   Economy  England
# freq       2234      2132                   13      2445      624
# first       NaN       NaN  2011-01-05 00:00:00       NaN      NaN
# last        NaN       NaN  2015-01-05 00:00:00       NaN      NaN

# %%
"""get customer order rate if more than once-> order month"""
orders_count = ListOfOrders.groupby(["Customer Name"])["Order ID"].nunique()
repeated_orders = np.sum(orders_count > 1) / ListOfOrders['Customer Name'].nunique()
print(f'{100 * repeated_orders:.2f}% of customers repeated their orders.')
# Out:
# 96.09% of customers repeated their orders.

# %%
ListOfOrders['OrderPeriod'] = ListOfOrders['Order Date'].apply(lambda x: x.strftime('%Y-%m'))
ListOfOrders.head() 
# calculate the cohort 
# ListOfOrders["Cohort"]= ???
# Out:
#           Order ID Order Date     Customer Name        City         Country  \
# 0  BN-2011-7407039 2011-01-01        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313 2011-01-03    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300 2011-01-04  Devin Huddleston     Valence          France
# 3  BN-2011-2819714 2011-01-04       Mary Parker  Birmingham  United Kingdom
# 4   AZ-2011-617423 2011-01-05      Daniel Burke  Echirolles          France
#
#     Region      Segment  Ship Date     Ship Mode                 State  \
# 0    North  Home Office 2011-01-05  Economy Plus             Stockholm
# 1    North     Consumer 2011-01-07       Economy               England
# 2  Central     Consumer 2011-01-08       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate 2011-01-09       Economy               England
# 4  Central  Home Office 2011-01-07      Priority  Auvergne-Rhône-Alpes
#
#   OrderPeriod
# 0     2011-01
# 1     2011-01
# 2     2011-01
# 3     2011-01
# 4     2011-01

# %% [markdown]
# track repeated purchases, for montioring or forcast trends.
# - Is there any high churn?
# - Is the customer engage more over the time? to see if the higher frequenctly the longer the customer stay with you.
